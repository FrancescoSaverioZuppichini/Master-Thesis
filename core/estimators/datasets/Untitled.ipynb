# %%
import glob 

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from pypeln import thread as th
from ipywidgets import interact, interactive, fixed, interact_manual

from TraversabilityDataset import TraversabilityDataset, get_transform

# %%
from PIL import Image

# %%
from skimage.util.shape import view_as_windows
import cv2

# %%
from torchvision.transforms.functional import rotate

# %%
img = cv2.imread('/home/francesco/Desktop/cat.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(img)

images = view_as_windows(img, 400, 100)


images[0][0]
plt.imshow(images[0][0])

img_pil = Image.fromarray(images[0][0])
rotate(img_pil, 270).show()
