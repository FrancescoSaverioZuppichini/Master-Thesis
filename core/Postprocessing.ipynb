# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Postprocessing
# <img src="https://github.com/FrancescoSaverioZuppichini/Master-Thesis/blob/master/papers/Thesis/img/postprocessing-pipeline.png?raw=tru" alt="drawing" width="500"/>
#
# ## Quick Start
# To postprocess a robot trajectory you just need to use the `Postprocessing` class contained into the [`postprocessing`](https://github.com/FrancescoSaverioZuppichini/Master-Thesis/tree/master/core/utilities/postprocessing) packages. Assuming you have this directory structure
#
# ```
# ├── test
# │   ├── bags
# ```

# %%
from utilities.postprocessing import PostProcessing
post = PostProcessing(root='/home/francesco/Desktop/test/',
                      maps_dir='/home/francesco/Documents/Master-Thesis/core/maps/new-train/',
                      advancement=0.45,
                      time_window=100)

post()
# Out:
# 0it [00:00, ?it/s]
#
#
# 1it [00:00,  2.76it/s]
#
#
# 2it [00:00,  5.48it/s]
#
#
# 0it [00:00, ?it/s]
#
#
# 1it [00:00,  1.24it/s]
#
#
# 2it [00:00,  2.47it/s]
#
#
# 0it [00:00, ?it/s]
#
#
# 1it [00:00,  1.33it/s]
#
#
# 2it [00:00,  1.74it/s]

# %%
! tree -L 2 /home/francesco/Desktop/test/
# Out:
# /home/francesco/Desktop/test/
# ├── 100
# │   ├── csvs
# │   └── patches
# ├── bags
# │   ├── bumps0-1-1563102050.8296146.bag
# │   └── bumps0-1-1563102061.9010878.bag
# ├── csvs
# │   ├── bumps0-1-1563102050.8296146.csv
# │   └── bumps0-1-1563102061.9010878.csv
# └── meta.csv
#
# 5 directories, 5 files

# %% [markdown]
# Where
# - `csvs/` contains the parsed `.bag` files with all the informations
# - `<TIME_WINDOW>/` contains
#     - `csvs/` a lightweight version of the `.csv` will only the information need for training
#     - `patches/` the ground patches

# %%
import pandas as pd

pd.read_csv('/home/francesco/Desktop/test/100/csvs/bumps0-1-1563102050.8296146.csv')
# Out:
#      Unnamed: 0  advancement                               images  height  \
# 0             0     0.643096    bumps0-1-1563102050.8296146-0.png       1
# 1             1     0.650371    bumps0-1-1563102050.8296146-1.png       1
# 2             2     0.656559    bumps0-1-1563102050.8296146-2.png       1
# 3             3     0.662917    bumps0-1-1563102050.8296146-3.png       1
# 4             4     0.666246    bumps0-1-1563102050.8296146-4.png       1
# 5             5     0.669118    bumps0-1-1563102050.8296146-5.png       1
# 6             6     0.673802    bumps0-1-1563102050.8296146-6.png       1
# 7             7     0.679604    bumps0-1-1563102050.8296146-7.png       1
# 8             8     0.687475    bumps0-1-1563102050.8296146-8.png       1
# 9             9     0.665514    bumps0-1-1563102050.8296146-9.png       1
# 10           10     0.670840   bumps0-1-1563102050.8296146-10.png       1
# 11           11     0.678744   bumps0-1-1563102050.8296146-11.png       1
# ...

# %% [markdown]
# ## API
# All steps of the pipeline are available as independent function in the [handlers](https://github.com/FrancescoSaverioZuppichini/Master-Thesis/blob/master/core/utilities/postprocessing/handlers/functional.py) subpackage inside `postprocessing`

# %%
from utilities.postprocessing.handlers.functional import add_advancement, extract_patches

df = pd.read_csv('/home/francesco/Desktop/test/csvs/bumps0-1-1563102050.8296146.csv')

df = add_advancement(df, 150)
df
# Out:
#      timestamp                     Unnamed: 0  pose__pose_position_x  \
# 0     1.068194  2019-07-14 11:00:39.820141568               2.369507
# 1     1.125787  2019-07-14 11:00:39.877734656               2.369507
# 2     1.188110  2019-07-14 11:00:39.940057088               2.369507
# 3     1.248123  2019-07-14 11:00:40.000070144               2.369517
# 4     1.314384  2019-07-14 11:00:40.066331136               2.369538
# 5     1.369372  2019-07-14 11:00:40.121319936               2.369550
# 6     1.426388  2019-07-14 11:00:40.178335232               2.369584
# 7     1.495584  2019-07-14 11:00:40.247531008               2.369677
# 8     1.517735  2019-07-14 11:00:40.269682176               2.369729
# 9     2.018838  2019-07-14 11:00:40.770785024               2.345194
# 10    2.040427  2019-07-14 11:00:40.792374272               2.344078
# 11    2.061267  2019-07-14 11:00:40.813214464               2.343737
# 12    2.081743  2019-07-14 11:00:40.833690624               2.343625
# ...

# %% [markdown]
# We also wrap each function into an `Handler` class in order to use little library called [pipeline](https://github.com/FrancescoSaverioZuppichini/Master-Thesis/tree/master/core/utilities/pipeline). The library allows to write a cascate of function and to easily add multi-thread support. Each Handler can be found [here](https://github.com/FrancescoSaverioZuppichini/Master-Thesis/blob/master/core/utilities/postprocessing/handlers/handlers.py)

# %% [markdown]
# ## Visualization
# We also implement some easily to use classes to visualize the dataset, you can find it [here](https://github.com/FrancescoSaverioZuppichini/Master-Thesis/blob/master/core/utilities/visualisation/__init__.py)

# %%
from utilities.visualisation import DataFrameVisualization

vis = DataFrameVisualization.from_path('/home/francesco/Desktop/test/csvs/bumps0-1-1563102050.8296146.csv', time_window=100)
vis(0.2)
# Out:
# /home/francesco/.local/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# /home/francesco/.local/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# /home/francesco/.local/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
from utilities.visualisation import PatchesAndDataframeVisualization

vis = PatchesAndDataframeVisualization.from_df_path_and_hm_path('/home/francesco/Desktop/test/csvs/bumps0-1-1563102050.8296146.csv', 
                                                               '/home/francesco/Documents/Master-Thesis/core/maps/new-train/bumps0.png',
                                                               hm_dir='/home/francesco/Desktop/test/100/patches/',
                                                               time_window=100)
vis.show_patches_on_the_map()
